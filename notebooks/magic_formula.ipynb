# %%
import pandas as pd
import yahoo_fin.stock_info as si

import yfinance as yf

# %%
ticker = yf.Ticker("POLY.L")

# %%
ticker.info
# Out:
# {'zip': '3031',
#  'sector': 'Basic Materials',
#  'fullTimeEmployees': 14281,
#  'longBusinessSummary': 'Polymetal International plc operates as a precious metals mining company in Russia, Kazakhstan, East Asia, and Europe. It operates through five segments: Magadan, Ural, Khabarovsk, Kazakhstan, and Yakutia. The company is involved in the exploration, extraction, processing, and reclamation of gold, silver, copper, zinc, and platinum group metals. Its flagship project is the Kyzyl property located in the East Kazakhstan Region, Kazakhstan. Polymetal International plc was founded in 1998 and is headquartered in Limassol, Cyprus.',
#  'city': 'Limassol',
#  'phone': '357 2 5558090',
#  'country': 'Cyprus',
#  'companyOfficers': [],
#  'website': 'https://www.polymetalinternational.com',
#  'maxAge': 1,
#  'address1': 'Parthenonos, 6',
#  'fax': '357 2 5260816',
#  'industry': 'Other Precious Metals & Mining',
#  'address2': '3rd floor',
#  'ebitdaMargins': 0.56269,
#  'profitMargins': 0.06156,
#  'grossMargins': 0.58408,
#  'operatingCashflow': 432000000,
#  'revenueGrowth': -0.177,
#  'operatingMargins': 0.24099001,
#  'ebitda': 1499000064,
#  'targetLowPrice': 2.99,
#  'recommendationKey': 'hold',
#  'grossProfits': 1759000000,
#  'freeCashflow': -452624992,
#  'targetMedianPrice': 16.51,
#  'currentPrice': 242,
#  'earningsGrowth': None,
#  'currentRatio': 1.751,
#  'returnOnAssets': 0.06546,
#  'numberOfAnalystOpinions': 3,
#  'targetMeanPrice': 12.32,
#  'debtToEquity': 103.699,
#  'returnOnEquity': 0.06197,
#  'targetHighPrice': 17.45,
#  'totalCash': 541000000,
#  'totalDebt': 3392000000,
#  'totalRevenue': 2664000000,
#  'totalCashPerShare': 1.142,
#  'financialCurrency': 'USD',
#  'revenuePerShare': 5.625,
#  'quickRatio': 0.56,
#  'recommendationMean': 3,
#  'exchange': 'LSE',
#  'shortName': 'POLYMETAL INTERNATIONAL PLC',
#  'longName': 'Polymetal International plc',
#  'exchangeTimezoneName': 'Europe/London',
#  'exchangeTimezoneShortName': 'GMT',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '0',
#  'quoteType': 'EQUITY',
#  'symbol': 'POLY.L',
#  'messageBoardId': 'finmb_12701813',
#  'market': 'gb_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': 1.499,
#  'beta3Year': None,
#  'enterpriseToEbitda': 2.663,
#  '52WeekChange': -0.8124758,
#  'morningStarRiskRating': None,
#  'forwardEps': 1.49,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 473625984,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'totalAssets': None,
#  'bookValue': 6.906,
#  'sharesShort': None,
#  'sharesPercentSharesOut': None,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1640908800,
#  'heldPercentInstitutions': 0.30296,
#  'netIncomeToCommon': 164000000,
#  'trailingEps': 153.5,
#  'lastDividendValue': 52,
#  'SandP52WeekChange': -0.1573345,
#  'priceToBook': 35.041992,
#  'heldPercentInsiders': 0.28614,
#  'nextFiscalYearEnd': 1703980800,
#  'yield': None,
#  'mostRecentQuarter': 1656547200,
#  'shortRatio': None,
#  'sharesShortPreviousMonthDate': None,
#  'floatShares': 375746640,
#  'beta': 0.567959,
#  'enterpriseValue': 3992439296,
#  'priceHint': 2,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': None,
#  'lastSplitFactor': None,
#  'legalType': None,
#  'lastDividendDate': 1651708800,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': None,
#  'priceToSalesTrailing12Months': 0.43024588,
#  'dateShortInterest': None,
#  'pegRatio': -3.24,
#  'ytdReturn': None,
#  'forwardPE': 1.6241611,
#  'lastCapGain': None,
#  'shortPercentOfFloat': None,
#  'sharesShortPriorMonth': None,
#  'impliedSharesOutstanding': 0,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'previousClose': 241,
#  'regularMarketOpen': 238.5,
#  'twoHundredDayAverage': 219.44835,
#  'trailingAnnualDividendYield': 0.0021576763,
#  'payoutRatio': None,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 244,
#  'navPrice': None,
#  'averageDailyVolume10Day': 272355,
#  'regularMarketPreviousClose': 241,
#  'fiftyDayAverage': 223.664,
#  'trailingAnnualDividendRate': 0.52,
#  'open': 238.5,
#  'toCurrency': None,
#  'averageVolume10days': 272355,
#  'expireDate': None,
#  'algorithm': None,
#  'dividendRate': None,
#  'exDividendDate': 1651708800,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 236.5,
#  'currency': 'GBp',
#  'trailingPE': 0.015765473,
#  'regularMarketVolume': 298046,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 1146174976,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 387856,
#  'dayLow': 236.5,
#  'ask': 251,
#  'askSize': 0,
#  'volume': 298046,
#  'fiftyTwoWeekHigh': 1331.901,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': 7.15,
#  'fiftyTwoWeekLow': 92.02,
#  'bid': 231,
#  'tradeable': False,
#  'dividendYield': None,
#  'bidSize': 0,
#  'dayHigh': 244,
#  'coinMarketCapLink': None,
#  'regularMarketPrice': 242,
#  'preMarketPrice': None,
#  'logo_url': 'https://logo.clearbit.com/polymetalinternational.com',
#  'trailingPegRatio': None}

# %%
income_statement = ticker.financials
income_statement
# Out:
#                                           2021-12-31    2020-12-31  \
# Research Development                            None          None
# Effect Of Accounting Charges                    None          None
# Income Before Tax                       1161000000.0  1380000000.0
# Minority Interest                                NaN           NaN
# Net Income                               904000000.0  1066000000.0
# Selling General Administrative           226000000.0   184000000.0
# Gross Profit                            1759000000.0  1892000000.0
# Ebit                                    1236000000.0  1454000000.0
# Operating Income                        1236000000.0  1454000000.0
# Other Operating Expenses                 225000000.0   211000000.0
# Interest Expense                         -54000000.0   -62000000.0
# Extraordinary Items                             None          None
# Non Recurring                                   None          None
# Other Items                                     None          None
# Income Tax Expense                       257000000.0   314000000.0
# Total Revenue                           2890000000.0  2865000000.0
# Total Operating Expenses                1654000000.0  1411000000.0
# Cost Of Revenue                         1131000000.0   973000000.0
# Total Other Income Expense Net           -75000000.0   -74000000.0
# Discontinued Operations                          NaN           NaN
# Net Income From Continuing Ops           904000000.0  1066000000.0
# Net Income Applicable To Common Shares   904000000.0  1066000000.0
#
#                                           2019-12-31    2018-12-31
# Research Development                            None          None
# Effect Of Accounting Charges                    None          None
# Income Before Tax                        634000000.0   426000000.0
# Minority Interest                         23000000.0    18000000.0
# Net Income                               480000000.0   354000000.0
# Selling General Administrative           181000000.0   175000000.0
# Gross Profit                            1180000000.0   893000000.0
# Ebit                                     812000000.0   553000000.0
# Operating Income                         812000000.0   553000000.0
# Other Operating Expenses                 168000000.0   152000000.0
# Interest Expense                         -75000000.0   -67000000.0
# Extraordinary Items                             None          None
# Non Recurring                                   None          None
# Other Items                                     None          None
# Income Tax Expense                       135000000.0    71000000.0
# Total Revenue                           2241000000.0  1882000000.0
# Total Operating Expenses                1429000000.0  1329000000.0
# Cost Of Revenue                         1061000000.0   989000000.0
# Total Other Income Expense Net          -178000000.0  -127000000.0
# Discontinued Operations                  -16000000.0     3000000.0
# Net Income From Continuing Ops           499000000.0   355000000.0
# Net Income Applicable To Common Shares   480000000.0   354000000.0

# %%
balance_sheet = ticker.balance_sheet
balance_sheet
# Out:
#                                                 2021-12-31    2020-12-31  \
# Total Liab                                    2.948000e+09  2.431000e+09
# Total Stockholder Equity                      2.203000e+09  1.960000e+09
# Other Current Liab                            2.120000e+08  9.200000e+07
# Total Assets                                  5.151000e+09  4.391000e+09
# Common Stock                                  2.450000e+09  2.434000e+09
# Other Current Assets                          1.370000e+08  1.260000e+08
# Retained Earnings                             1.587000e+09  1.318000e+09
# Other Liab                                    3.850000e+08  3.690000e+08
# Good Will                                     1.400000e+07  1.400000e+07
# Gains Losses Not Affecting Retained Earnings -1.834000e+09 -1.792000e+09
# Other Assets                                  2.200000e+08  2.080000e+08
# Cash                                          4.170000e+08  3.860000e+08
# Total Current Liabilities                     9.160000e+08  6.320000e+08
# Deferred Long Term Asset Charges              6.700000e+07  5.600000e+07
# Short Long Term Debt                          4.460000e+08  3.340000e+08
# Other Stockholder Equity                     -1.834000e+09 -1.792000e+09
# Property Plant Equipment                      3.347000e+09  2.770000e+09
# Total Current Assets                          1.542000e+09  1.375000e+09
# Long Term Investments                         2.800000e+07  2.400000e+07
# Net Tangible Assets                           2.189000e+09  1.946000e+09
# Net Receivables                               2.020000e+08  1.990000e+08
# Long Term Debt                                1.618000e+09  1.403000e+09
# Inventory                                     7.810000e+08  6.620000e+08
# Accounts Payable                              1.210000e+08  9.000000e+07
# Minority Interest                                      NaN           NaN
#
#                                                 2019-12-31    2018-12-31
# Total Liab                                    2.293000e+09  2.438000e+09
# Total Stockholder Equity                      1.928000e+09  1.379000e+09
# Other Current Liab                            3.700000e+07  1.440000e+08
# Total Assets                                  4.244000e+09  3.835000e+09
# Common Stock                                  2.424000e+09  2.414000e+09
# Other Current Assets                          9.400000e+07  1.260000e+08
# Retained Earnings                             7.800000e+08  5.400000e+08
# Other Liab                                    3.150000e+08  2.350000e+08
# Good Will                                     1.600000e+07  1.500000e+07
# Gains Losses Not Affecting Retained Earnings -1.276000e+09 -1.575000e+09
# Other Assets                                  1.970000e+08  1.810000e+08
# Cash                                          2.530000e+08  3.790000e+08
# Total Current Liabilities                     4.310000e+08  4.210000e+08
# Deferred Long Term Asset Charges              7.300000e+07  7.300000e+07
# Short Long Term Debt                          2.140000e+08  1.170000e+08
# Other Stockholder Equity                     -1.276000e+09 -1.575000e+09
# Property Plant Equipment                      2.841000e+09  2.419000e+09
# Total Current Assets                          1.188000e+09  1.218000e+09
# Long Term Investments                         2.000000e+06  2.000000e+06
# Net Tangible Assets                           1.912000e+09  1.364000e+09
# Net Receivables                               1.900000e+08  1.760000e+08
# Long Term Debt                                1.518000e+09  1.782000e+09
# Inventory                                     6.440000e+08  5.370000e+08
# Accounts Payable                              7.300000e+07  7.200000e+07
# Minority Interest                             2.300000e+07  1.800000e+07

# %%
cashflow = ticker.cashflow
cashflow
# Out:
#                                              2021-12-31    2020-12-31  \
# Investments                               -1.000000e+07 -2.400000e+07
# Change To Liabilities                      1.000000e+06  3.400000e+07
# Total Cashflows From Investing Activities -7.880000e+08 -5.640000e+08
# Net Borrowings                             2.760000e+08 -1.000000e+06
# Total Cash From Financing Activities      -3.720000e+08 -4.700000e+08
# Change To Operating Activities             1.500000e+08  2.000000e+06
# Net Income                                 9.040000e+08  1.066000e+09
# Change In Cash                             3.100000e+07  1.330000e+08
# Effect Of Exchange Rate                   -4.000000e+06 -4.000000e+06
# Total Cash From Operating Activities       1.195000e+09  1.167000e+09
# Depreciation                               2.180000e+08  2.020000e+08
# Dividends Paid                            -6.350000e+08 -3.870000e+08
# Change To Inventory                       -1.450000e+08 -1.700000e+08
# Change To Account Receivables             -3.000000e+06 -2.600000e+07
# Other Cashflows From Financing Activities -1.300000e+07  1.200000e+07
# Change To Netincome                        6.700000e+07  5.600000e+07
# Capital Expenditures                      -7.590000e+08 -5.580000e+08
# Other Cashflows From Investing Activities           NaN           NaN
#
#                                             2019-12-31   2018-12-31
# Investments                                -24000000.0  -24000000.0
# Change To Liabilities                      -16000000.0  134000000.0
# Total Cashflows From Investing Activities -397000000.0 -379000000.0
# Net Borrowings                            -169000000.0  443000000.0
# Total Cash From Financing Activities      -422000000.0  224000000.0
# Change To Operating Activities             -45000000.0  -16000000.0
# Net Income                                 480000000.0  354000000.0
# Change In Cash                            -126000000.0  343000000.0
# Effect Of Exchange Rate                     -3000000.0  -15000000.0
# Total Cash From Operating Activities       696000000.0  513000000.0
# Depreciation                               247000000.0  176000000.0
# Dividends Paid                            -240000000.0 -213000000.0
# Change To Inventory                        -93000000.0 -184000000.0
# Change To Account Receivables              -54000000.0  -24000000.0
# Other Cashflows From Financing Activities  -13000000.0   -6000000.0
# Change To Netincome                        174000000.0   73000000.0
# Capital Expenditures                      -436000000.0 -344000000.0
# Other Cashflows From Investing Activities   43000000.0  -51000000.0

# %%
earnings = ticker.earnings
earnings
# Out:
#          Revenue    Earnings
# Year
# 2018  1882000000   354000000
# 2019  2241000000   480000000
# 2020  2865000000  1066000000
# 2021  2890000000   904000000

# %%
import pickle
file = open('poly.pkl', 'wb')
pickle.dump(ticker, file)
file.close()

# %%
file = open('poly.pkl', 'rb')
ticker2 = pickle.load(file)
file.close()

# %%
ticker2.financials
# Out:
#                                           2021-12-31    2020-12-31  \
# Research Development                            None          None
# Effect Of Accounting Charges                    None          None
# Income Before Tax                       1161000000.0  1380000000.0
# Minority Interest                                NaN           NaN
# Net Income                               904000000.0  1066000000.0
# Selling General Administrative           226000000.0   184000000.0
# Gross Profit                            1759000000.0  1892000000.0
# Ebit                                    1236000000.0  1454000000.0
# Operating Income                        1236000000.0  1454000000.0
# Other Operating Expenses                 225000000.0   211000000.0
# Interest Expense                         -54000000.0   -62000000.0
# Extraordinary Items                             None          None
# Non Recurring                                   None          None
# Other Items                                     None          None
# Income Tax Expense                       257000000.0   314000000.0
# Total Revenue                           2890000000.0  2865000000.0
# Total Operating Expenses                1654000000.0  1411000000.0
# Cost Of Revenue                         1131000000.0   973000000.0
# Total Other Income Expense Net           -75000000.0   -74000000.0
# Discontinued Operations                          NaN           NaN
# Net Income From Continuing Ops           904000000.0  1066000000.0
# Net Income Applicable To Common Shares   904000000.0  1066000000.0
#
#                                           2019-12-31    2018-12-31
# Research Development                            None          None
# Effect Of Accounting Charges                    None          None
# Income Before Tax                        634000000.0   426000000.0
# Minority Interest                         23000000.0    18000000.0
# Net Income                               480000000.0   354000000.0
# Selling General Administrative           181000000.0   175000000.0
# Gross Profit                            1180000000.0   893000000.0
# Ebit                                     812000000.0   553000000.0
# Operating Income                         812000000.0   553000000.0
# Other Operating Expenses                 168000000.0   152000000.0
# Interest Expense                         -75000000.0   -67000000.0
# Extraordinary Items                             None          None
# Non Recurring                                   None          None
# Other Items                                     None          None
# Income Tax Expense                       135000000.0    71000000.0
# Total Revenue                           2241000000.0  1882000000.0
# Total Operating Expenses                1429000000.0  1329000000.0
# Cost Of Revenue                         1061000000.0   989000000.0
# Total Other Income Expense Net          -178000000.0  -127000000.0
# Discontinued Operations                  -16000000.0     3000000.0
# Net Income From Continuing Ops           499000000.0   355000000.0
# Net Income Applicable To Common Shares   480000000.0   354000000.0
