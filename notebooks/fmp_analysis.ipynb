# %%
import pickle
import pandas as pd
from datetime import datetime
import queue
import threading

import fundamentalanalysis as fa
import fa_mods as famods
import fa_utils

with open('/home/craigc/.keys/financialmodelingprep.txt', 'r') as file:
    api_key = file.read()

# %%
with open(f'../data/all_nyse_stock_data_221220.pkl', 'rb') as file:
    nyse_data = pickle.load(file)

print(len(nyse_data))
# Out:
# 2528

# %%
ticker = 'EC'
display(nyse_data[ticker].keys())
display(nyse_data[ticker]['key_metrics'])
# fa.profile(ticker, api_key)
# Out:
# dict_keys(['timestamp', 'income_statement', 'income_statement_growth', 'cashflow_statement', 'cashflow_statement_growth', 'balance_sheet_statement', 'balance_sheet_statement_growth', 'discounted_cash_flow', 'advanced_discounted_cash_flow', 'advanced_levered_discounted_cash_flow', 'key_metrics', 'financial_ratios', 'growth', 'owner_earnings', 'enterprise_values', 'dividends', 'scores'])
#                                                        2021  \
# revenuePerShare                                   12.874073
# netIncomePerShare                                  3.047331
# operatingCashFlowPerShare                          5.794299
# freeCashFlowPerShare                               4.824519
# cashPerShare                                       1.704512
# bookValuePerShare                                 10.641817
# tangibleBookValuePerShare                         10.240106
# shareholdersEquityPerShare                        10.641817
# ...
